# %%
import pandas as pd

df  = pd.read_csv('stops.txt')
df2 = pd.read_csv('stops_arabic (1).csv')

# add last column in df2 to df
df['stop_name_ar'] = df2['stop_name_ar']
df.to_csv('stops.txt', index=False)
